# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from transformers import pipeline
from scipy.sparse import csr_matrix
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

paragraphs_df = pd.read_excel('/content/paragraphs.xlsx')
queries_df = pd.read_excel('/content/queries.xlsx')


qa_pipeline = pipeline('question-answering')


def preprocess_text(text):
    return text.lower()


paragraphs= paragraphs_df.iloc[:,2].tolist()
queries= queries_df.iloc[:,0].tolist()
# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer()
paragraph_vectors = tfidf_vectorizer.fit_transform(paragraphs)
query_vectors = tfidf_vectorizer.transform(queries)

# Function to get top N relevant paragraphs
def get_top_n_paragraphs(query_vector, paragraph_vectors, n=5):
    similarities = cosine_similarity(query_vector, paragraph_vectors).flatten()
    top_n_indices = similarities.argsort()[-n:][::-1]
    return paragraphs_df.iloc[top_n_indices]

def get_answer(paragraph, query):
    qa_input = {
        'question': query,
        'context': paragraph
    }
    answer = qa_pipeline(qa_input)
    return answer['answer'], answer['score']


for idx, query_row in queries_df.iterrows():
    query = query_row['query']
    query_vector = query_vectors[idx]
    top_paragraphs = get_top_n_paragraphs(query_vector, paragraph_vectors, n=5)

    found_answer = False
    for _, para_row in top_paragraphs.iterrows():
        paragraph = para_row['paragraph']
        answer, score = get_answer(paragraph, query)
        if score > 0.5:
            print(f"Query: {query}")
            print(f"Paragraph: {paragraph}")
            print(f"Answer: {answer}\n")
            found_answer = True
            break

    if not found_answer:
        print(f"Query: {query}")
        print("No valid answer found.\n")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-75f14d03d58d> in <cell line: 27>()
#      25 # TF-IDF Vectorization
#      26 tfidf_vectorizer = TfidfVectorizer()
# ---> 27 paragraph_vectors = tfidf_vectorizer.fit_transform(paragraphs)
#      28 query_vectors = tfidf_vectorizer.transform(queries)
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from transformers import pipeline
from scipy.sparse import csr_matrix
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns


paragraphs_df = pd.read_excel('/content/paragraphs.xlsx')
queries_df = pd.read_excel('/content/queries.xlsx')

qa_pipeline = pipeline('question-answering')


def preprocess_text(text):
    return text.lower()

paragraphs_df['paragraph'] = paragraphs_df['paragraph'].apply(preprocess_text)
queries_df['query'] = queries_df['query'].apply(preprocess_text)

paragraphs_df = paragraphs_df.dropna(subset=['paragraph'])
queries_df = queries_df.dropna(subset=['query'])

paragraphs = paragraphs_df['paragraph'].tolist()
queries = queries_df['query'].tolist()

tfidf_vectorizer = TfidfVectorizer()
paragraph_vectors = tfidf_vectorizer.fit_transform(paragraphs)
query_vectors = tfidf_vectorizer.transform(queries)

# Function to get top N relevant paragraphs
def get_top_n_paragraphs(query_vector, paragraph_vectors, n=5):
    similarities = cosine_similarity(query_vector, paragraph_vectors).flatten()
    top_n_indices = similarities.argsort()[-n:][::-1]
    return paragraphs_df.iloc[top_n_indices]

# Function to get answer from a paragraph
def get_answer(paragraph, query):
    qa_input = {
        'question': query,
        'context': paragraph
    }
    answer = qa_pipeline(qa_input)
    return answer['answer'], answer['score']

# Process each query
for idx, query_row in queries_df.iterrows():
    query = query_row['query']
    query_vector = query_vectors[idx]
    top_paragraphs = get_top_n_paragraphs(query_vector, paragraph_vectors, n=5)

    found_answer = False
    for _, para_row in top_paragraphs.iterrows():
        paragraph = para_row['paragraph']
        answer, score = get_answer(paragraph, query)
        if score > 0.5:
            print(f"Query: {query}")
            print(f"Paragraph: {paragraph}")
            print(f"Answer: {answer}\n")
            found_answer = True
            break

    if not found_answer:
        print(f"Query: {query}")
        print("No valid answer found.\n")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from transformers import pipeline
from scipy.sparse import csr_matrix
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

# Load datasets
paragraphs_df = pd.read_excel('/content/paragraphs.xlsx')  # Replace with the actual path to paragraphs.xlsx
queries_df = pd.read_excel('/content/queries.xlsx')  # Replace with the actual path to queries.xlsx

# Inspect the column names
print("Paragraphs DataFrame columns:", paragraphs_df.columns)
print("Queries DataFrame columns:", queries_df.columns)

# Ensure correct column names
  # Update this if the column name is different

# Check if the columns exist


# Pre-trained QA model from Hugging Face transformers
qa_pipeline = pipeline('question-answering')

# Text preprocessing function
def preprocess_text(text):
    return text.lower()

# Apply preprocessing
paragraphs_df[paragraph_column] = paragraphs_df[paragraph_column].apply(preprocess_text)
queries_df[query_column] = queries_df[query_column].apply(preprocess_text)

# Handle missing values
paragraphs_df = paragraphs_df.dropna(subset=[paragraph_column])
queries_df = queries_df.dropna(subset=[query_column])

# Extract paragraphs and queries as lists
paragraphs = paragraphs_df[paragraph_column].tolist()
queries = queries_df[query_column].tolist()

# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer()
paragraph_vectors = tfidf_vectorizer.fit_transform(paragraphs)
query_vectors = tfidf_vectorizer.transform(queries)

# Function to get top N relevant paragraphs
def get_top_n_paragraphs(query_vector, paragraph_vectors, n=5):
    similarities = cosine_similarity(query_vector, paragraph_vectors).flatten()
    top_n_indices = similarities.argsort()[-n:][::-1]
    return paragraphs_df.iloc[top_n_indices]

# Function to get answer from a paragraph
def get_answer(paragraph, query):
    qa_input = {
        'question': query,
        'context': paragraph
    }
    answer = qa_pipeline(qa_input)
    return answer['answer'], answer['score']

# Process each query
for idx, query_row in queries_df.iterrows():
    query = query_row[query_column]
    query_vector = query_vectors[idx]
    top_paragraphs = get_top_n_paragraphs(query_vector, paragraph_vectors, n=5)

    found_answer = False
    for _, para_row in top_paragraphs.iterrows():
        paragraph = para_row[paragraph_column]
        answer, score = get_answer(paragraph, query)
        if score > 0.5:  # Threshold for answer validity
            print(f"Query: {query}")
            print(f"Paragraph: {paragraph}")
            print(f"Answer: {answer}\n")
            found_answer = True
            break

    if not found_answer:
        print(f"Query: {query}")
        print("No valid answer found.\n")
# Out:
# Paragraphs DataFrame columns: Index([                                                                                                                                                                                                                                                                                                                                                               25909,
#                                                                                                                                                                                                                                                                                                                                                                  'Zhejiang',
# ...
